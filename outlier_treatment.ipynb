# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency    sector 7   0.45          5000.0
# 1          flat            apna enclave    sector 3   0.50          7692.0
# 2          flat  tulsiani easy in homes  sohna road   0.40          6722.0
# 3          flat     smart world orchard   sector 61   1.47         12250.0
# 4          flat        parkwood westend   sector 92   0.70          5204.0
#
#      area                            areaWithType  bedRoom  bathroom balcony  \
# 0   900.0          Carpet area: 900 (83.61 sq.m.)        2         2       1
# 1   650.0          Carpet area: 650 (60.39 sq.m.)        2         2       1
# 2   595.0          Carpet area: 595 (55.28 sq.m.)        2         2       3
# 3  1200.0        Carpet area: 1200 (111.48 sq.m.)        2         2       2
# 4  1345.0  Super Built up area 1345(124.95 sq.m.)        2         2       3
#
# ...

# %%
sns.distplot(df['price'])
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\444587821.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (425,
#  count    425.000000
#  mean       9.235624
#  std        4.065259
#  min        5.460000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 3715         house  arjun marg/ sector- 26 phase- 1/ golf course road
# 3485         house                                        independent
# 3476         house                                        independent
# 3518         house                                     dlf city plots
# 3654         house                                   suncity township
# 3441         house                             emaar the palm springs
# 3640         house                                        independent
# 3459         house                                 vipul tatvam villa
# 2949         house                             luxury dlf city floors
# 3434         house                                     dlf city plots
# 3568         house                                        independent
# 3581         house                                        independent
# ...

# %%
outliers.to_csv('price_outliers.csv')

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (354,
#  count       354.000000
#  mean      52592.612994
#  std       61150.458507
#  min       24489.000000
#  25%       28208.250000
#  50%       33368.500000
#  75%       41982.250000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
outliers_sqft.to_csv('outliers_price_per_sqft.csv')

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x : x*9 if x<1000 else x)
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\4226659558.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x : x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round(outliers_sqft['price']*10000000)/outliers_sqft['area']
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\2758877875.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round(outliers_sqft['price']*10000000)/outliers_sqft['area']

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29357.901761
# std      12403.087704
# min       2723.311547
# 25%      25562.372188
# 50%      29870.794599
# 75%      35549.095607
# max      82539.682540
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x = df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 50000]
# Out:
#      property_type                       society      sector  price  \
# 2659          flat                unitech vistas   sector 70   9.00
# 3147         house                  malibu towne   sector 47   8.50
# 3304         house  project housing board colony   sector 31   8.00
# 3418         house            cloudnine cottages  sohna road   5.50
# 3433         house                   independent   sector 26  14.75
# 3441         house        emaar the palm springs   sector 54  24.00
# 3476         house                   independent   sector 26  26.00
# 3518         house                dlf city plots   sector 26  26.00
# 3603         house        emaar the palm springs   sector 54  14.00
# 3667         house            emaar mgf marbella   sector 66  18.00
# 3679         house                   independent   sector 25  16.00
# 3707         house                unitech escape   sector 50  10.80
# 3775         house                           nul   sector 28  12.50
#
# ...

# %%
df =df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x = df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
sns.distplot(df['price'])
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\444587821.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3647.000000
# mean       2947.723608
# std       23208.194102
# min         145.000000
# 25%        1262.000000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 110           flat      signature the roselia   sector 95   0.45
# 1291          flat            ramsons kshitij   sector 95   0.31
# 1950          flat  signature global solera 2  sector 107   0.51
# 2408          flat          hcbs sports ville  sohna road   0.35
# 3253         house                independent   sector 50   5.00
#
#       price_per_sqft      area                           areaWithType  \
# 110              7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
# 1291             5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
# 1950             9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
# 2408             4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 3253           232.0  215517.0             Plot area 2(1011.71 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 110         2         2       2       2.0  South-West    New Property
# ...

# %%
df = df[df['area'] < 100000]

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 10000].sort_values('area', ascending = False)
# Out:
#      property_type                    society      sector  price  \
# 3559         house                independent   sector 26  18.40
# 3222         house  ganpati heights apartment   sector 13   1.25
# 2304          flat                 rof ananda   sector 95   0.38
# 1293          flat                 rof ananda   sector 95   0.38
# 3294         house      dlf city plot phase 4   sector 28  13.00
# 79            flat              pyramid elite   sector 86   0.46
# 1292          flat                 rof ananda   sector 95   0.33
# 1415          flat      signature the serenas  sohna road   0.28
# 3471         house                independent   sector 25   7.30
# 1289          flat            ramsons kshitij   sector 95   0.24
# 1294          flat                 rof ananda   sector 95   0.21
# 3049         house                independent   sector 57   6.25
# 3533         house                independent   sector 43   5.50
# ...

# %%
df.drop(index=[2304, 1293, 79, 1292, 1415, 1289, 1294, 3042, 3559], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society      sector  price  \
# 3222         house  ganpati heights apartment   sector 13   1.25
# 3294         house      dlf city plot phase 4   sector 28  13.00
# 3471         house                independent   sector 25   7.30
# 3049         house                independent   sector 57   6.25
# 3533         house                independent   sector 43   5.50
# 2399          flat                 godrej air   sector 85   2.50
# 3056         house       unitech aspen greens   sector 50   6.95
# 2801          flat                godrej icon  sector 88a   1.75
# 3485         house                independent   sector 43  27.50
# 1622          flat             m3m golfestate   sector 65  13.20
# 3420         house                independent  sohna road   5.50
#
#       price_per_sqft     area  \
# 3222           151.0  82781.0
# 3294          1992.0  65261.0
# 3471          1560.0  46795.0
# 3049          2778.0  22498.0
# ...

# %%
df.loc[3222,'area'] = 115*9
df.loc[3294,'area'] = 7250
df.loc[3471,'area'] = 5800
df.loc[3049,'area'] = 2660
df.loc[3533,'area'] = 2850
df.loc[2399,'area'] = 1812
df.loc[3056,'area'] = 2160
df.loc[2801,'area'] = 1175
df.loc[2801,'sector'] = 'sector 88'

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type         society      sector  price  price_per_sqft  \
# 3485         house     independent   sector 43   27.5         24366.0
# 1622          flat  m3m golfestate   sector 65   13.2         12000.0
# 3420         house     independent  sohna road    5.5          5093.0
#
#          area                                       areaWithType  bedRoom  \
# 3485  11286.0                       Plot area 1254(1048.5 sq.m.)        6
# 1622  11000.0                 Carpet area: 11000 (1021.93 sq.m.)        4
# 3420  10799.0  Plot area 1200(1003.35 sq.m.)Built Up area: 35...        3
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 3485         7      3+       3.0  North-East  Relatively New
# 1622         4       3      13.0       North  Moderately Old
# 3420         3      3+       2.0        West  Moderately Old
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 3485                  NaN        11286.0          NaN           1
# ...

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
indices = [3222, 3294, 3471, 3049, 3533, 2399, 3056, 2801]
print(df.loc[indices, ['price', 'area', 'price_per_sqft']])
# Out:
#       price    area  price_per_sqft
# 3222   1.25  1035.0           151.0
# 3294  13.00  7250.0          1992.0
# 3471   7.30  5800.0          1560.0
# 3049   6.25  2660.0          2778.0
# 3533   5.50  2850.0          2716.0
# 2399   2.50  1812.0          1379.0
# 3056   6.95  2160.0          4490.0
# 2801   1.75  1175.0          1384.0

# %%
# Now update price_per_sqft for these indices
indices = [3222, 3294, 3471, 3049, 3533, 2399, 3056, 2801]
for idx in indices:
    df.loc[idx, 'price_per_sqft'] = df.loc[idx, 'price']*10000000 / df.loc[idx, 'area']

# %%
indices = [3222, 3294, 3471, 3049, 3533, 2399, 3056, 2801]
print(df.loc[indices, ['price', 'area', 'price_per_sqft']])
# Out:
#       price    area  price_per_sqft
# 3222   1.25  1035.0    12077.294686
# 3294  13.00  7250.0    17931.034483
# 3471   7.30  5800.0    12586.206897
# 3049   6.25  2660.0    23496.240602
# 3533   5.50  2850.0    19298.245614
# 2399   2.50  1812.0    13796.909492
# 3056   6.95  2160.0    32175.925926
# 2801   1.75  1175.0    14893.617021

# %%
sns.boxplot(x = df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
sns.distplot(x = df['price_per_sqft'])
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\161683301.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = df['price_per_sqft'])
# <Axes: ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count     3633.000000
# mean      1950.357005
# std       1215.707897
# min        145.000000
# 25%       1260.000000
# 50%       1747.000000
# 75%       2325.000000
# max      11286.000000
# Name: area, dtype: float64

# %%
df['price_per_sqft'].describe()
# Out:
# count     3633.000000
# mean     11553.215975
# std       7580.189960
# min        544.000000
# 25%       6779.000000
# 50%       8947.000000
# 75%      13492.000000
# max      50000.000000
# Name: price_per_sqft, dtype: float64

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3633.000000
# mean        3.333609
# std         1.830035
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending = False)
# Out:
#      property_type                      society      sector  price  \
# 2945         house                  independent   sector 54   5.00
# 2947         house                  independent   sector 43   4.50
# 3402         house                  independent   sector 17   3.87
# 3070         house                  independent   sector 17   3.93
# 3650         house                  independent   sector 54   5.50
# 3050         house                private house   sector 55   7.05
# 3668         house                  independent   sector 40  12.00
# 3630         house                  independent   sector 55   9.19
# 2981         house                  independent   sector 43  13.50
# 2983         house                  independent   sector 56  12.39
# 3434         house               dlf city plots   sector 26  20.00
# 2949         house       luxury dlf city floors   sector 26  20.00
# 3051         house                  independent   sector 11   4.50
# ...

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3588, 23)

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
sns.distplot(df['bathroom'])
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\2904465235.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending = False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 3379         house  adani brahma samsara  sector 60  18.02    28200.312989
# 3324         house           independent  sector 39   7.00    10000.000000
# 3378         house           independent  sector 24  11.00    28901.734104
#
#         area                                       areaWithType  bedRoom  \
# 3379  6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 3324  7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
# 3378  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 3379        12      3+       3.0  North-East  Relatively New
# 3324        11      3+       4.0  South-East  Relatively New
# 3378        11      3+       3.0        East    Old Property
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %%
sns.distplot(df['super_built_up_area'])
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\4184943455.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(df['super_built_up_area'])
# Out:
# <Axes: ylabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society     sector  price  \
# 657           flat       krrish provence estate  sector 55    7.5
# 1528          flat  bestech park view grand spa  sector 81    4.7
#
#       price_per_sqft     area                             areaWithType  \
# 657           7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
# 1528          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 657         5         6      3+      23.0  North-East  Relatively New
# 1528        4         4      3+      19.0       North  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 657               10000.0            NaN          NaN           0
# 1528               6926.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %%
sns.distplot(df['built_up_area'])
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(df['built_up_area'])
# Out:
# <Axes: ylabel='built_up_area'>

# %%
sns.boxplot(df['built_up_area'])
# Out:
# <Axes: ylabel='built_up_area'>

# %%
sns.distplot(df['carpet_area'])
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(df['carpet_area'])
# Out:
# <Axes: ylabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 1622          flat  m3m golfestate  sector 65   13.2    12000.000000  11000.0
# 2399          flat      godrej air  sector 85    2.5    13796.909492   1812.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 1622  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
# 2399  Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 1622       North  Moderately Old                  NaN            NaN
# 2399  North-East       Undefined                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 1622      11000.0           0             1           0           0       0
# 2399      18122.0           1             0           0           1       1
#
#       furnishing_type  luxury_score
# ...

# %%
df.loc[2399,'carpet_area'] = 1812

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 1622          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 1622  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#      facing   agePossession  super_built_up_area  built_up_area  carpet_area  \
# 1622  North  Moderately Old                  NaN            NaN      11000.0
#
#       study room  servant room  store room  pooja room  others  \
# 1622           0             1           0           0       0
#
#       furnishing_type  luxury_score
# 1622                1            60

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency    sector 7   0.45          5000.0
# 1          flat            apna enclave    sector 3   0.50          7692.0
# 2          flat  tulsiani easy in homes  sohna road   0.40          6722.0
# 3          flat     smart world orchard   sector 61   1.47         12250.0
# 4          flat        parkwood westend   sector 92   0.70          5204.0
#
#      area                            areaWithType  bedRoom  bathroom balcony  \
# 0   900.0          Carpet area: 900 (83.61 sq.m.)        2         2       1
# 1   650.0          Carpet area: 650 (60.39 sq.m.)        2         2       1
# 2   595.0          Carpet area: 595 (55.28 sq.m.)        2         2       3
# 3  1200.0        Carpet area: 1200 (111.48 sq.m.)        2         2       2
# 4  1345.0  Super Built up area 1345(124.95 sq.m.)        2         2       3
#
# ...

# %%
sns.distplot(df['luxury_score'])
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
sns.boxplot(df['luxury_score'])
# Out:
# <Axes: ylabel='luxury_score'>

# %%
df['price_per_sqft'] = round(df['price']*10000000/df['area'])

# %%
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency    sector 7   0.45          5000.0
# 1          flat            apna enclave    sector 3   0.50          7692.0
# 2          flat  tulsiani easy in homes  sohna road   0.40          6723.0
# 3          flat     smart world orchard   sector 61   1.47         12250.0
# 4          flat        parkwood westend   sector 92   0.70          5204.0
#
#      area                            areaWithType  bedRoom  bathroom balcony  \
# 0   900.0          Carpet area: 900 (83.61 sq.m.)        2         2       1
# 1   650.0          Carpet area: 650 (60.39 sq.m.)        2         2       1
# 2   595.0          Carpet area: 595 (55.28 sq.m.)        2         2       3
# 3  1200.0        Carpet area: 1200 (111.48 sq.m.)        2         2       2
# 4  1345.0  Super Built up area 1345(124.95 sq.m.)        2         2       3
#
# ...

# %%
df.shape
# Out:
# (3588, 23)

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.02)
# Out:
# 183.33333333333334

# %%
df[(df['area']/df['bedRoom'])<183]
# Out:
#      property_type                                 society      sector  price  \
# 2958         house                             independent   sector 38   2.10
# 3062         house                             independent   sector 12   1.00
# 3072         house                             independent    sector 7   0.90
# 3074         house                               prem kunj  sohna road   0.50
# 3076         house                             independent  sector 105   0.60
# 3077         house                             independent    sector 3   0.50
# 3088         house                             independent    sector 1   0.80
# 3096         house                             independent   sector 12   0.90
# 3097         house                                 my home  sector 110   0.34
# 3105         house                   rajendra park gurgaon  sector 105   0.37
# 3108         house                             independent    sector 8   0.49
# ...

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(.05)
# Out:
# 250.5

# %%
temp = df[(df['area']/df['bedRoom'])<250]
temp['area_bedroom_ratio'] = temp['area']/temp['bedRoom']
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\3812362960.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['area_bedroom_ratio'] = temp['area']/temp['bedRoom']

# %%
sns.lmplot(data=df,x='area',y = 'bedRoom')

# %%
temp.to_csv('areaa_bedroom.csv')

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']

# %%
(df[df['area_room_ratio'] < 250])['bedRoom'].value_counts()
# Out:
# bedRoom
# 2     47
# 3     33
# 5     28
# 6     17
# 4     17
# 9     15
# 8     12
# 7      8
# 10     8
# Name: count, dtype: int64

# %%
df = df[df['area_room_ratio'] > 100]

# %%
outliers_df = df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 3)]

# %%
outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_12556\3450078040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])

# %%
df.update(outliers_df)

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']
df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 4)]
# Out:
#      property_type               society      sector  price  price_per_sqft  \
# 3081         house           independent    sector 1   1.10          6173.0
# 3088         house           independent    sector 1   0.80          6667.0
# 3090         house              shivpuri    sector 7   2.80         12444.0
# 3094         house           independent    sector 7   1.16         11717.0
# 3141         house           independent   sector 12   2.50         13889.0
# 3150         house  bhim nagar, sector 6    sector 6   0.85         14096.0
# 3202         house           independent    sector 3   1.10         10000.0
# 3228         house           independent   sector 12   0.65          6500.0
# 3243         house           independent  sector 105   1.10         12222.0
# 3300         house           independent   sector 17   0.32          5664.0
# 3335         house           independent    sector 2   0.98          9074.0
# ...

# %%
df = df[~((df['area_room_ratio'] < 250) & (df['bedRoom'] > 4))]

# %%
sns.lmplot(data=df,x='area',y = 'bedRoom')

# %%
df.to_csv('gurgaon_properties_outlier_treated.csv' , index = False)
