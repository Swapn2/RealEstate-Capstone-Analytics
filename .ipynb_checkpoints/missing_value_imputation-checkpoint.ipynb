# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('gurgaon_properties_outlier_treated.csv')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    Unnamed: 0 property_type                 society      sector  price  \
# 0           0          flat  maa bhagwati residency    sector 7   0.45
# 1           1          flat            apna enclave    sector 3   0.50
# 2           2          flat  tulsiani easy in homes  sohna road   0.40
# 3           3          flat     smart world orchard   sector 61   1.47
# 4           4          flat        parkwood westend   sector 92   0.70
#
#    price_per_sqft    area                            areaWithType  bedRoom  \
# 0          5000.0   900.0          Carpet area: 900 (83.61 sq.m.)        2
# 1          7692.0   650.0          Carpet area: 650 (60.39 sq.m.)        2
# 2          6723.0   595.0          Carpet area: 595 (55.28 sq.m.)        2
# 3         12250.0  1200.0        Carpet area: 1200 (111.48 sq.m.)        2
# 4          5204.0  1345.0  Super Built up area 1345(124.95 sq.m.)        2
#
#    bathroom balcony  floorNum facing       agePossession  super_built_up_area  \
# 0         2       1       4.0   West      Relatively New                  NaN
# 1         2       1       1.0   West        Old Property                  NaN
# 2         2       3      12.0    NaN        New Property                  NaN
# 3         2       2       2.0    NaN           Undefined                  NaN
# 4         2       3       5.0    NaN  Under Construction               1345.0
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0            NaN        900.0           0             0           0
# 1            NaN        650.0           0             0           0
# 2            NaN        595.0           0             0           0
# 3            NaN       1200.0           1             0           0
# 4            NaN          NaN           1             0           0
#
#    pooja room  others  furnishing_type  luxury_score  area_room_ratio
# 0           0       0                1            28            450.0
# 1           0       0                0            37            325.0
# 2           0       0                1            36            297.5
# 3           0       0                1            76            600.0
# 4           0       0                1             0            672.5

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1011
# agePossession             0
# super_built_up_area    1680
# built_up_area          1968
# carpet_area            1715
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
sns.scatterplot(x = df['built_up_area'],y = df['super_built_up_area'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='super_built_up_area'>

# %%
sns.scatterplot(x = df['built_up_area'],y = df['carpet_area'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='carpet_area'>

# %%
((df['super_built_up_area'].isnull()) & ( df['built_up_area'].isnull()) & (df['carpet_area'].isnull()))
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3550    False
# 3551    False
# 3552    False
# 3553    False
# 3554    False
# Length: 3555, dtype: bool

# %%
all_present_df = df[(~(df['super_built_up_area'].isnull()) & ~( df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull()))]

# %%
all_present_df
# Out:
#       Unnamed: 0 property_type                society     sector  price  \
# 37            38          flat             ild greens  sector 37   0.78
# 99           101          flat     emaar palm premier  sector 77   2.10
# 129          132          flat   umang monsoon breeze  sector 78   0.90
# 132          135          flat     supertech araville  sector 79   0.90
# 137          140          flat         bhagwati sadan  sector 12   1.15
# ...          ...           ...                    ...        ...    ...
# 2731        2869          flat          prime habitat  sector 99   0.32
# 2746        2884          flat           apna enclave   sector 3   0.55
# 2748        2886          flat  shri balaji apartment  sector 12   0.35
# 2787        2925          flat     supertech araville  sector 79   1.35
# 2795        2933          flat    palam vihar society   sector 2   0.40
#
#       price_per_sqft    area  \
# 37            5714.0  1365.0
# 99           10500.0  2000.0
# 129           4615.0  1950.0
# 132           5882.0  1530.0
# 137           5750.0  2000.0
# ...              ...     ...
# 2731          4658.0   687.0
# 2746          5789.0   950.0
# 2748          4037.0   867.0
# 2787          9000.0  1500.0
# 2795          8602.0   465.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 37    Super Built up area 1365(126.81 sq.m.)Built Up...        2         2
# 99    Super Built up area 2000(185.81 sq.m.)Built Up...        3         4
# 129   Super Built up area 1950(181.16 sq.m.)Built Up...        3         3
# 132   Super Built up area 1530(142.14 sq.m.)Built Up...        2         2
# 137   Super Built up area 2500(232.26 sq.m.)Built Up...        3         4
# ...                                                 ...      ...       ...
# 2731  Super Built up area 687(63.82 sq.m.)Built Up a...        2         2
# 2746  Super Built up area 950(88.26 sq.m.)Built Up a...        2         2
# 2748  Super Built up area 867(80.55 sq.m.)Built Up a...        2         2
# 2787  Super Built up area 1530(142.14 sq.m.)Built Up...        2         2
# 2795  Super Built up area 465(43.2 sq.m.)Built Up ar...        1         1
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 37         3       1.0       North  Moderately Old               1365.0
# 99        3+      11.0         NaN    New Property               2000.0
# 129        2       1.0         NaN  Moderately Old               1950.0
# 132        3       5.0         NaN  Relatively New               1530.0
# 137        2       2.0         NaN    Old Property               2500.0
# ...      ...       ...         ...             ...                  ...
# 2731       1       7.0         NaN  Relatively New                687.0
# 2746       2       2.0  North-East    Old Property                950.0
# 2748       1       1.0       North  Moderately Old                867.0
# 2787       3       6.0        East    New Property               1530.0
# 2795       1       5.0       North  Moderately Old                465.0
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 37           1068.1        900.0           0             0           0
# 99           1600.0       1500.0           0             1           0
# 129          1900.0       1854.0           0             1           0
# 132          1450.0       1400.0           1             0           0
# 137          2000.0       1750.0           1             1           0
# ...             ...          ...         ...           ...         ...
# 2731          601.0        448.0           0             0           0
# 2746          900.0        744.0           0             0           0
# 2748          737.0        650.0           0             0           0
# 2787         1350.0       1200.0           1             0           0
# 2795          450.0        425.0           0             0           0
#
#       pooja room  others  furnishing_type  luxury_score  area_room_ratio
# 37             0       0                0           103       682.500000
# 99             0       0                0           129       666.666667
# 129            1       0                1            65       650.000000
# 132            0       0                1            53       765.000000
# 137            0       1                0            28       666.666667
# ...          ...     ...              ...           ...              ...
# 2731           0       0                1            44       343.500000
# 2746           0       0                1            66       475.000000
# 2748           0       0                1            23       433.500000
# 2787           0       1                0            88       750.000000
# 2795           0       0                0            39       465.000000
#
# [531 rows x 25 columns]

# %%
all_present_df.shape
# Out:
# (531, 25)

# %%
super_to_built_up_ratio = (all_present_df['super_built_up_area']/all_present_df['built_up_area']).median()

# %%
carpet_to_built_up_ratio = (all_present_df['carpet_area']/all_present_df['built_up_area']).median()

# %%
print(super_to_built_up_ratio , carpet_to_built_up_ratio)
# Out:
# 1.105263157894737 0.9

# %%
sbc_df = df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
sbc_df
# Out:
#       Unnamed: 0 property_type                             society  \
# 30            31          flat                         bhawna cghs
# 35            36          flat                   chintels paradiso
# 36            37          flat              breez global hill view
# 57            58          flat              silverglades the melia
# 59            60          flat                  umang winter hills
# ...          ...           ...                                 ...
# 2764        2902          flat                         green court
# 2779        2917          flat  laxmi apartment sector 99a gurgaon
# 2780        2918          flat                         godrej aria
# 2781        2919          flat                       ansal estella
# 2789        2927          flat                umang monsoon breeze
#
#           sector  price  price_per_sqft    area  \
# 30     sector 43   3.25         10156.0  3200.0
# 35    sector 109   1.80          8867.0  2030.0
# 36    sohna road   0.30          5405.0   555.0
# 57    sohna road   1.01          6999.0  1443.0
# 59     sector 77   0.99          7857.0  1260.0
# ...          ...    ...             ...     ...
# 2764   sector 90   0.50          8333.0   600.0
# 2779   sector 99   0.30          4615.0   650.0
# 2780   sector 79   1.95          8519.0  2289.0
# 2781  sector 103   1.50          8671.0  1730.0
# 2789   sector 78   1.20          6494.0  1848.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 30    Super Built up area 3200(297.29 sq.m.)Carpet a...        4         4
# 35    Super Built up area 2030(188.59 sq.m.)Carpet a...        3         3
# 36    Super Built up area 655(60.85 sq.m.)Carpet are...        2         2
# 57    Super Built up area 1450(134.71 sq.m.)Carpet a...        2         2
# 59    Super Built up area 1260(117.06 sq.m.)Carpet a...        2         2
# ...                                                 ...      ...       ...
# 2764  Super Built up area 700(65.03 sq.m.)Carpet are...        2         2
# 2779  Super Built up area 650(60.39 sq.m.)Carpet are...        2         2
# 2780  Super Built up area 2289(212.66 sq.m.)Carpet a...        3         4
# 2781  Super Built up area 1730(160.72 sq.m.)Carpet a...        3         3
# 2789  Super Built up area 2250(209.03 sq.m.)Carpet a...        3         3
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 30        3+      12.0         NaN      Moderately Old               3200.0
# 35         2       0.0        East      Moderately Old               2030.0
# 36         2       6.0  North-East        New Property                655.0
# 57         3      12.0         NaN           Undefined               1450.0
# 59         2       1.0       North      Relatively New               1260.0
# ...      ...       ...         ...                 ...                  ...
# 2764       1       8.0         NaN        New Property                700.0
# 2779       1       4.0         NaN        New Property                650.0
# 2780      3+      10.0         NaN        New Property               2289.0
# 2781      3+       6.0         NaN  Under Construction               1730.0
# 2789       2       8.0         NaN      Moderately Old               2250.0
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 30              NaN       3000.0           0             0           0
# 35              NaN       1785.0           0             1           0
# 36              NaN        555.0           0             0           0
# 57              NaN        950.0           1             0           0
# 59              NaN       1000.0           0             0           0
# ...             ...          ...         ...           ...         ...
# 2764            NaN        600.0           0             0           0
# 2779            NaN        550.0           0             0           0
# 2780            NaN       1121.0           0             1           0
# 2781            NaN       1725.0           0             0           0
# 2789            NaN       1848.0           0             0           0
#
#       pooja room  others  furnishing_type  luxury_score  area_room_ratio
# 30             1       0                0           119       800.000000
# 35             0       0                1            83       676.666667
# 36             0       0                1           109       277.500000
# 57             0       0                1            80       721.500000
# 59             0       0                1            97       630.000000
# ...          ...     ...              ...           ...              ...
# 2764           0       0                1            42       300.000000
# 2779           0       0                1            44       325.000000
# 2780           0       0                1            32       763.000000
# 2781           0       0                1            58       576.666667
# 2789           1       0                2             8       616.000000
#
# [421 rows x 25 columns]

# %%
sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/.9))/2),inplace = True)
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_4416\1223733319.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/.9))/2),inplace = True)
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_4416\1223733319.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/.9))/2),inplace = True)

# %%
df.update(sbc_df)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1011
# agePossession             0
# super_built_up_area    1680
# built_up_area          1547
# carpet_area            1715
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
sb_df = df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull())]

# %%
sb_df
# Out:
#       Unnamed: 0 property_type                     society      sector  price  \
# 4              4          flat            parkwood westend   sector 92   0.70
# 6              6          flat                  the cocoon    sector 9   2.00
# 13            13          flat                      godrej   sector 33   0.95
# 14            14          flat        shree vardhman flora   sector 90   0.70
# 18            19          flat  central park flower valley   sector 33   2.20
# ...          ...           ...                         ...         ...    ...
# 2796        2934          flat               m3m woodshire  sector 107   1.40
# 2797        2935          flat          krishna appartment   sector 12   0.35
# 2800        2938          flat            ansal heights 86   sector 86   1.05
# 2802        2940          flat             raheja vedaanta  sector 108   0.95
# 2804        2942          flat               dlf the crest   sector 54  11.00
#
#       price_per_sqft    area                            areaWithType  bedRoom  \
# 4             5204.0  1345.0  Super Built up area 1345(124.95 sq.m.)        2
# 6            13333.0  1500.0  Super Built up area 1500(139.35 sq.m.)        3
# 13            6859.0  1385.0  Super Built up area 1385(128.67 sq.m.)        2
# 14            5385.0  1300.0  Super Built up area 1300(120.77 sq.m.)        2
# 18           10476.0  2100.0   Super Built up area 2100(195.1 sq.m.)        3
# ...              ...     ...                                     ...      ...
# 2796          5930.0  2361.0  Super Built up area 2361(219.34 sq.m.)        3
# 2797          3500.0  1000.0    Super Built up area 1000(92.9 sq.m.)        3
# 2800          5541.0  1895.0  Super Built up area 1895(176.05 sq.m.)        3
# 2802          5214.0  1822.0  Super Built up area 1822(169.27 sq.m.)        3
# 2804         35223.0  3123.0  Super Built up area 3123(290.14 sq.m.)        4
#
#       bathroom balcony  floorNum      facing       agePossession  \
# 4            2       3       5.0         NaN  Under Construction
# 6            3       3       5.0         NaN        New Property
# 13           2      3+       3.0  South-East  Under Construction
# 14           2       3      13.0         NaN        New Property
# 18           3       3      12.0  North-East        New Property
# ...        ...     ...       ...         ...                 ...
# 2796         4       0       1.0        East        New Property
# 2797         3       1       2.0         NaN        Old Property
# 2800         3       3       9.0  North-East  Under Construction
# 2802         3       3       3.0         NaN      Relatively New
# 2804         6       3       7.0         NaN      Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 4                  1345.0            NaN          NaN           1
# 6                  1500.0            NaN          NaN           0
# 13                 1385.0            NaN          NaN           0
# 14                 1300.0            NaN          NaN           1
# 18                 2100.0            NaN          NaN           0
# ...                   ...            ...          ...         ...
# 2796               2361.0            NaN          NaN           0
# 2797               1000.0            NaN          NaN           0
# 2800               1895.0            NaN          NaN           0
# 2802               1822.0            NaN          NaN           0
# 2804               3123.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# 4                0           0           0       0                1
# 6                0           0           0       0                1
# 13               0           0           0       0                1
# 14               0           0           0       0                1
# 18               1           0           0       0                0
# ...            ...         ...         ...     ...              ...
# 2796             0           0           0       0                1
# 2797             0           0           0       0                1
# 2800             1           0           0       0                1
# 2802             0           0           0       1                1
# 2804             1           0           0       0                2
#
#       luxury_score  area_room_ratio
# 4                0       672.500000
# 6                0       500.000000
# 13               0       692.500000
# 14              15       650.000000
# 18              49       700.000000
# ...            ...              ...
# 2796            67       787.000000
# 2797             0       333.333333
# 2800             0       631.666667
# 2802            95       607.333333
# 2804           125       780.750000
#
# [875 rows x 25 columns]

# %%
sb_df['built_up_area'] = sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105))
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_4416\3536697853.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_df['built_up_area'] = sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105))

# %%
df.update(sb_df)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1011
# agePossession             0
# super_built_up_area    1680
# built_up_area           672
# carpet_area            1715
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
c_df = df[(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
c_df
# Out:
#       Unnamed: 0 property_type                 society      sector  price  \
# 0              0          flat  maa bhagwati residency    sector 7   0.45
# 1              1          flat            apna enclave    sector 3   0.50
# 2              2          flat  tulsiani easy in homes  sohna road   0.40
# 3              3          flat     smart world orchard   sector 61   1.47
# 7              7          flat             ats triumph  sector 104   1.80
# ...          ...           ...                     ...         ...    ...
# 3428        3659         house    bptp astaire gardens  sector 70a   1.04
# 3431        3662         house    bptp astaire gardens  sector 70a   1.18
# 3432        3663         house           bptp pedestal  sector 70a   0.90
# 3441        3674         house      emaar mgf marbella   sector 66  19.00
# 3463        3700         house             independent   sector 26  18.25
#
#       price_per_sqft     area  \
# 0             5000.0    900.0
# 1             7692.0    650.0
# 2             6723.0    595.0
# 3            12250.0   1200.0
# 7             7860.0   2290.0
# ...              ...      ...
# 3428          7172.0   1450.0
# 3431          8138.0   1450.0
# 3432          7582.0   1187.0
# 3441         31667.0   6000.0
# 3463         18250.0  10000.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 0                        Carpet area: 900 (83.61 sq.m.)        2         2
# 1                        Carpet area: 650 (60.39 sq.m.)        2         2
# 2                        Carpet area: 595 (55.28 sq.m.)        2         2
# 3                      Carpet area: 1200 (111.48 sq.m.)        2         2
# 7                      Carpet area: 2290 (212.75 sq.m.)        3         4
# ...                                                 ...      ...       ...
# 3428                   Carpet area: 1450 (134.71 sq.m.)        3         3
# 3431                   Carpet area: 1450 (134.71 sq.m.)        3         3
# 3432                   Carpet area: 1187 (110.28 sq.m.)        2         2
# 3441  Plot area 9000(836.13 sq.m.)Carpet area: 6000 ...        5         6
# 3463  Plot area 550(51.1 sq.m.)Carpet area: 10000 sq...        7         9
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 0          1       4.0        West  Relatively New                  NaN
# 1          1       1.0        West    Old Property                  NaN
# 2          3      12.0         NaN    New Property                  NaN
# 3          2       2.0         NaN       Undefined                  NaN
# 7          3      14.0         NaN    New Property                  NaN
# ...      ...       ...         ...             ...                  ...
# 3428      3+       2.0  North-East  Relatively New                  NaN
# 3431      3+       2.0  North-East  Relatively New                  NaN
# 3432      3+       3.0  North-East    New Property                  NaN
# 3441      3+       3.0  North-East  Relatively New                  NaN
# 3463      3+       4.0        East  Relatively New                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 0               NaN        900.0           0             0           0
# 1               NaN        650.0           0             0           0
# 2               NaN        595.0           0             0           0
# 3               NaN       1200.0           1             0           0
# 7               NaN       2290.0           0             0           0
# ...             ...          ...         ...           ...         ...
# 3428            NaN       1450.0           0             0           0
# 3431            NaN       1450.0           0             0           0
# 3432            NaN       1187.0           0             1           0
# 3441            NaN       6000.0           0             1           1
# 3463            NaN      10000.0           1             1           1
#
#       pooja room  others  furnishing_type  luxury_score  area_room_ratio
# 0              0       0                1            28       450.000000
# 1              0       0                0            37       325.000000
# 2              0       0                1            36       297.500000
# 3              0       0                1            76       600.000000
# 7              0       0                1            60       763.333333
# ...          ...     ...              ...           ...              ...
# 3428           0       1                0           145       483.333333
# 3431           0       1                0           153       483.333333
# 3432           0       1                1           153       593.500000
# 3441           1       0                0           110      1200.000000
# 3463           1       0                0            77      1428.571429
#
# [672 rows x 25 columns]

# %%
c_df['built_up_area'] = c_df['built_up_area'].fillna(round(c_df['carpet_area']/1.105))
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_4416\2296892546.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_df['built_up_area'] = c_df['built_up_area'].fillna(round(c_df['carpet_area']/1.105))

# %%
df.update(c_df)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1011
# agePossession             0
# super_built_up_area    1680
# built_up_area             0
# carpet_area            1715
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
sns.scatterplot(x=df['built_up_area'], y = df['price'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
anamoly_df = df[(df['built_up_area'] < 2000) & (df['price'] > 2.5)][['price','area','built_up_area']]

# %%
anamoly_df.sample(5)
# Out:
#       price    area  built_up_area
# 2661   2.75  1640.0         1484.0
# 2839   2.55  1557.0         1557.0
# 2931   6.00  1800.0         1800.0
# 972    2.58  2200.0         1991.0
# 2941   7.25  2471.0          303.0

# %%
anamoly_df['built_up_area'] = anamoly_df['area']

# %%
df.update(anamoly_df)

# %%
sns.scatterplot(x = df['built_up_area'], y = df['price'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
df.drop(columns=['area','areaWithType','super_built_up_area','carpet_area','area_room_ratio'],inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 property_type                 society      sector  price  \
# 0           0          flat  maa bhagwati residency    sector 7   0.45
# 1           1          flat            apna enclave    sector 3   0.50
# 2           2          flat  tulsiani easy in homes  sohna road   0.40
# 3           3          flat     smart world orchard   sector 61   1.47
# 4           4          flat        parkwood westend   sector 92   0.70
#
#    price_per_sqft  bedRoom  bathroom balcony  floorNum facing  \
# 0          5000.0        2         2       1       4.0   West
# 1          7692.0        2         2       1       1.0   West
# 2          6723.0        2         2       3      12.0    NaN
# 3         12250.0        2         2       2       2.0    NaN
# 4          5204.0        2         2       3       5.0    NaN
#
#         agePossession  built_up_area  study room  servant room  store room  \
# 0      Relatively New          814.0           0             0           0
# 1        Old Property          588.0           0             0           0
# 2        New Property          538.0           0             0           0
# 3           Undefined         1086.0           1             0           0
# 4  Under Construction         1217.0           1             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                1            28
# 1           0       0                0            37
# 2           0       0                1            36
# 3           0       0                1            76
# 4           0       0                1             0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# property_type         0
# society               1
# sector                0
# price                 0
# price_per_sqft        0
# bedRoom               0
# bathroom              0
# balcony               0
# floorNum             17
# facing             1011
# agePossession         0
# built_up_area         0
# study room            0
# servant room          0
# store room            0
# pooja room            0
# others                0
# furnishing_type       0
# luxury_score          0
# dtype: int64

# %%
df[df['floorNum'].isnull()]
# Out:
#       Unnamed: 0 property_type                  society      sector  price  \
# 169          172          flat       experion heartsong  sector 108   1.08
# 2573        2711          flat                      NaN   sector 78   0.60
# 2821        2964         house       vipul tatvam villa   sector 48   8.50
# 2840        2989         house              independent    sector 2   5.60
# 2911        3065         house              independent   sector 24   1.45
# 2942        3102         house              independent    sector 3   1.50
# 2955        3117         house              independent    sector 4   4.12
# 3001        3173         house              independent    sector 4   0.65
# 3016        3189         house  ansal sushant lok plots   sector 43   3.30
# 3135        3325         house               jacob pura   sector 12   0.35
# 3159        3352         house              independent   sector 25  13.00
# 3207        3407         house              independent    sector 7   6.50
# 3340        3558         house     dlf new town heights   sector 86   2.47
# 3357        3578         house       vipul tatvam villa   sector 48   8.50
# 3362        3585         house        ansal sushant lok   sector 43  10.50
# 3365        3588         house              independent   sector 26   4.60
# 3481        3719         house       emaar mgf marbella   sector 66   9.00
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum      facing  \
# 169           6150.0        3         3       0       NaN         NaN
# 2573          3692.0        2         2       0       NaN         NaN
# 2821         26235.0        4         4       2       NaN        East
# 2840         17284.0        8         6      3+       NaN  South-West
# 2911          2984.0        3         3       1       NaN         NaN
# 2942         10288.0        3         3       0       NaN         NaN
# 2955          8889.0        2         1      3+       NaN         NaN
# 3001         11111.0        4         2       2       NaN         NaN
# 3016         26570.0        1         1       0       NaN         NaN
# 3135          9722.0        2         1       0       NaN         NaN
# 3159         45710.0        6         8      3+       NaN         NaN
# 3207         15046.0        3         2      3+       NaN         NaN
# 3340          7719.0        4         4      3+       NaN        West
# 3357         26235.0        4         4       1       NaN         NaN
# 3362         27911.0        4         4       2       NaN  North-East
# 3365         12198.0        4         4      3+       NaN         NaN
# 3481         21251.0        4         4      3+       NaN  South-West
#
#            agePossession  built_up_area  study room  servant room  store room  \
# 169   Under Construction         1758.0           0             0           0
# 2573  Under Construction         1625.0           0             0           0
# 2821      Moderately Old         3240.0           0             1           1
# 2840      Moderately Old         3240.0           1             1           1
# 2911        Old Property          540.0           0             0           0
# 2942        Old Property          210.0           0             0           0
# 2955      Moderately Old         4635.0           0             0           0
# 3001      Moderately Old          585.0           0             0           0
# 3016  Under Construction         1242.0           0             0           0
# 3135        Old Property          360.0           0             0           0
# 3159      Relatively New         2844.0           1             1           1
# 3207        Old Property         4320.0           0             0           0
# 3340      Moderately Old         2800.0           0             1           0
# 3357      Relatively New         3240.0           0             0           0
# 3362        Old Property         3762.0           0             1           0
# 3365        Old Property         3771.0           0             0           0
# 3481      Relatively New         5200.0           0             1           1
#
#       pooja room  others  furnishing_type  luxury_score
# 169            0       0                1             0
# 2573           0       0                1             0
# 2821           1       0                1            88
# 2840           1       0                1             0
# 2911           0       0                1             9
# 2942           0       0                1             0
# 2955           0       0                1             0
# 3001           0       0                1             0
# 3016           0       0                1             0
# 3135           0       0                1             0
# 3159           1       0                2             0
# 3207           0       0                1             9
# 3340           1       0                0           130
# 3357           0       0                1            21
# 3362           0       0                1            59
# 3365           0       0                1            28
# 3481           1       0                0           114

# %%
df[df['property_type'] == 'house']['floorNum'].median()
# Out:
# 2.0

# %%
df['floorNum'].fillna(2.0,inplace=True)
df.isnull().sum()
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_4416\3049345725.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['floorNum'].fillna(2.0,inplace=True)
# Unnamed: 0            0
# property_type         0
# society               1
# sector                0
# price                 0
# price_per_sqft        0
# bedRoom               0
# bathroom              0
# balcony               0
# floorNum              0
# facing             1011
# agePossession         0
# built_up_area         0
# study room            0
# servant room          0
# store room            0
# pooja room            0
# others                0
# furnishing_type       0
# luxury_score          0
# dtype: int64

# %%
df['facing'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.drop(columns=['facing'],inplace=True)
df.sample(5)
# Out:
#       Unnamed: 0 property_type               society      sector  price  \
# 3468        3705         house           independent   sector 28  11.75
# 1876        1907          flat       eldeco accolade  sohna road   0.87
# 3215        3415         house           independent   sector 12   2.90
# 2577        2715          flat  shree vardhman flora   sector 90   0.95
# 1691        1722          flat     dlf regal gardens   sector 90   1.21
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum   agePossession  \
# 3468         41315.0        4         5      3+       4.0  Relatively New
# 1876          5963.0        2         2      3+      10.0  Relatively New
# 3215         10741.0        7         7       3       2.0    Old Property
# 2577          6333.0        3         3       3       9.0  Relatively New
# 1691          6926.0        3         3      3+      29.0  Relatively New
#
#       built_up_area  study room  servant room  store room  pooja room  others  \
# 3468         2844.0           1             1           1           0       0
# 1876         1131.0           1             0           0           0       0
# 3215         2700.0           0             0           0           0       0
# 2577         1357.0           0             1           0           0       0
# 1691         1581.0           0             0           0           0       1
#
#       furnishing_type  luxury_score
# 3468                0            54
# 1876                1            72
# 3215                1             7
# 2577                1            90
# 1691                1            95

# %%
df.drop(index=[2536],inplace=True)
df.isnull().sum()
# Out:
# Unnamed: 0         0
# property_type      0
# society            1
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1605
# New Property           557
# Moderately Old         544
# Undefined              431
# Old Property           293
# Under Construction     124
# Name: count, dtype: int64

# %%
df[df['agePossession'] == 'Undefined']
# Out:
#       Unnamed: 0 property_type                         society      sector  \
# 3              3          flat             smart world orchard   sector 61
# 5              5          flat  signature global infinity mall   sector 36
# 9              9          flat                  raheja revanta   sector 78
# 10            10          flat        signature global city 81   sector 81
# 15            15          flat                      sobha city  sector 108
# ...          ...           ...                             ...         ...
# 3199        3397         house                     independent   sector 43
# 3202        3401         house         project mianwali colony   sector 12
# 3301        3512         house             smart world orchard   sector 61
# 3321        3537         house              dlf floors phase 3   sector 24
# 3351        3571         house           signature global city   sector 37
#
#       price  price_per_sqft  bedRoom  bathroom balcony  floorNum  \
# 3      1.47         12250.0        2         2       2       2.0
# 5      0.41          6269.0        2         2       3       3.0
# 9      4.75         16886.0        3         3       2      31.0
# 10     0.96          9766.0        2         2       2       1.0
# 15     3.95         16859.0        4         5       3      25.0
# ...     ...             ...      ...       ...     ...       ...
# 3199   2.15         13030.0        1         1       0       1.0
# 3202   2.00         14815.0        5         5       2       3.0
# 3301   2.01         13001.0        3         3       3       4.0
# 3321   3.51         12342.0        4         4       3       4.0
# 3351   1.27          8089.0        3         3       3       4.0
#
#      agePossession  built_up_area  study room  servant room  store room  \
# 3        Undefined         1086.0           1             0           0
# 5        Undefined          654.0           0             0           0
# 9        Undefined         2813.0           0             1           0
# 10       Undefined          973.0           0             0           0
# 15       Undefined         2343.0           0             0           0
# ...            ...            ...         ...           ...         ...
# 3199     Undefined         1650.0           0             0           0
# 3202     Undefined         1350.0           0             0           0
# 3301     Undefined         1549.0           0             0           0
# 3321     Undefined         2844.0           1             1           1
# 3351     Undefined         1570.0           0             0           0
#
#       pooja room  others  furnishing_type  luxury_score
# 3              0       0                1            76
# 5              0       0                1             0
# 9              0       0                1           100
# 10             0       0                1            49
# 15             0       0                1            59
# ...          ...     ...              ...           ...
# 3199           0       0                1             0
# 3202           0       0                1             0
# 3301           0       0                1           145
# 3321           1       0                0           160
# 3351           1       0                1            89
#
# [431 rows x 19 columns]

# %%
def mode_based_imputation(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector']) & (df['property_type'] == row['property_type'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df[df['agePossession'] == 'Undefined'].iloc[0]
# Out:
# Unnamed: 0                           3
# property_type                     flat
# society            smart world orchard
# sector                       sector 61
# price                             1.47
# price_per_sqft                 12250.0
# bedRoom                              2
# bathroom                             2
# balcony                              2
# floorNum                           2.0
# agePossession                Undefined
# built_up_area                   1086.0
# study room                           1
# servant room                         0
# store room                           0
# pooja room                           0
# others                               0
# furnishing_type                      1
# luxury_score                        76
# Name: 3, dtype: object

# %%
df['agePossession'] = df.apply(mode_based_imputation,axis=1)

# %%
df['agePossession'].value_counts()

def mode_based_imputation2(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation2,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1814
# New Property           651
# Moderately Old         593
# Old Property           330
# Under Construction     126
# Undefined               40
# Name: count, dtype: int64

# %%
def mode_based_imputation3(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['property_type'] == row['property_type'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']
df['agePossession'] = df.apply(mode_based_imputation3,axis=1)
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1835
# New Property           651
# Moderately Old         612
# Old Property           330
# Under Construction     126
# Name: count, dtype: int64

# %%
df.to_csv('gurgaon_properties_missing_value_imputation.csv')
