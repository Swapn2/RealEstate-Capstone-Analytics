# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import KFold , cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from sklearn.decomposition import PCA

# %%
df = pd.read_csv('gurgaon_properties_post_feature_selection_v2.csv').drop(columns =['store room','floor_category','balcony'])

# %%
df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom       agePossession  \
# 0          flat    sector 7   0.45        2         2      Relatively New
# 1          flat    sector 3   0.50        2         2        Old Property
# 2          flat  sohna road   0.40        2         2        New Property
# 3          flat   sector 61   1.47        2         2        New Property
# 4          flat   sector 92   0.70        2         2  Under Construction
#
#    built_up_area  servant room  furnishing_type luxury_category
# 0          814.0             0                1             Low
# 1          588.0             0                0             Low
# 2          538.0             0                1             Low
# 3         1086.0             0                1          Medium
# 4         1217.0             0                1             Low

# %%
df['agePossession'] = df['agePossession'].replace(
    {'Relatively New' : 'new',
     'Moderately Old' : 'old',
     'New Property' : 'new',
     'Old Property' : 'old',
     'Under Construction' : 'under construction'
    }
)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# new                   2486
# old                    942
# under construction     126
# Name: count, dtype: int64

# %%
df['property_type'] = df['property_type'].replace({'flat': 0 , 'house': 1 })
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_13576\180572710.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['property_type'] = df['property_type'].replace({'flat': 0 , 'house': 1 })

# %%
df.head()
# Out:
#    property_type      sector  price  bedRoom  bathroom       agePossession  \
# 0              0    sector 7   0.45        2         2                 new
# 1              0    sector 3   0.50        2         2                 old
# 2              0  sohna road   0.40        2         2                 new
# 3              0   sector 61   1.47        2         2                 new
# 4              0   sector 92   0.70        2         2  under construction
#
#    built_up_area  servant room  furnishing_type luxury_category
# 0          814.0             0                1             Low
# 1          588.0             0                0             Low
# 2          538.0             0                1             Low
# 3         1086.0             0                1          Medium
# 4         1217.0             0                1             Low

# %%
df['luxury_category'] = df['luxury_category'].replace({'Low':0, 'Medium':1 , 'High' : 2})
# Out:
# C:\Users\SWAPN\AppData\Local\Temp\ipykernel_13576\2584274954.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['luxury_category'] = df['luxury_category'].replace({'Low':0, 'Medium':1 , 'High' : 2})

# %%
df.head()
# Out:
#    property_type      sector  price  bedRoom  bathroom       agePossession  \
# 0              0    sector 7   0.45        2         2                 new
# 1              0    sector 3   0.50        2         2                 old
# 2              0  sohna road   0.40        2         2                 new
# 3              0   sector 61   1.47        2         2                 new
# 4              0   sector 92   0.70        2         2  under construction
#
#    built_up_area  servant room  furnishing_type  luxury_category
# 0          814.0             0                1                0
# 1          588.0             0                0                0
# 2          538.0             0                1                0
# 3         1086.0             0                1                1
# 4         1217.0             0                1                0

# %%
new_df = pd.get_dummies(df, columns = ['sector' , 'agePossession'], drop_first= True )

# %%
new_df.shape
# Out:
# (3554, 106)

# %%
x = new_df.drop(columns=['price'])
y = new_df['price']

# %%
y_log = np.log1p(y)

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_scaled = pd.DataFrame(x_scaled , columns = x.columns)

# %%
kfold = KFold(n_splits = 10 , shuffle = True , random_state = 42)
scores = cross_val_score(LinearRegression() , x_scaled , y_log , cv= kfold , scoring = 'r2')

# %%
scores.mean() , scores.std()
# Out:
# (np.float64(0.8543377380386342), np.float64(0.023090800055170484))

# %%
lr = LinearRegression()
lr.fit(x_scaled , y_log)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([ 1.10405122e-01,  5.10700979e-02,  6.38960208e-02,  2.23109590e-01,
#         4.86685653e-02, -1.69051325e-03,  4.26061366e-03,  1.58682014e-02,
#         6.35282048e-02,  2.01208631e-02,  3.27754788e-02, -1.72016790e-03,
#         2.29714536e-02,  1.45901585e-02,  4.27360933e-02,  5.71857466e-02,
#         2.96428517e-04,  2.50524494e-02,  3.33809522e-02,  4.61652559e-02,
#         5.76569986e-02,  1.65210069e-03, -1.18394014e-03,  4.48292515e-02,
#         1.28506324e-02,  2.57329760e-02,  3.53548799e-02, -3.04355283e-05,
#         5.29093275e-02,  1.53851574e-02,  3.48731732e-02,  8.09617821e-02,
#         9.62644206e-02,  1.27502760e-02,  6.53497675e-02,  2.27683516e-03,
#         1.43887181e-02,  3.46746238e-02,  5.96278717e-02,  2.04305453e-02,
#         3.25800446e-02,  2.45077392e-02,  1.58741778e-02,  5.17021525e-03,
#         1.64059214e-02,  2.90460542e-02,  8.91897568e-02,  3.82159916e-02,
#         2.92712917e-02,  2.82533578e-02,  8.16400597e-02,  5.61455052e-02,
#         6.06878310e-03,  1.00063731e-01,  9.86054671e-03,  1.86564245e-02,
#         6.20925494e-02,  6.43033794e-02,  3.47346024e-02,  3.79844914e-02,
#         4.32021529e-02,  3.37626949e-02,  4.49455788e-02, -2.66057864e-03,
#         3.73356147e-02,  6.41829744e-02,  5.70397625e-02,  6.24221761e-02,
#         1.06638273e-01,  7.54890411e-02,  6.87597596e-02,  3.14410162e-02,
#         5.26427140e-02,  1.53723365e-02,  3.17399353e-02,  4.39443271e-02,
#         1.51107998e-02,  4.78397176e-02,  5.02971119e-03,  3.70914185e-02,
#         1.72748860e-02,  1.93347021e-02,  9.67707195e-03,  4.50972991e-02,
#        -2.83413498e-03,  7.89536062e-03,  5.01828792e-02,  3.43946044e-02,
#         2.86072835e-02,  1.41605326e-02,  4.42236547e-02,  2.46656662e-02,
#         1.00572022e-02,  2.54859336e-02,  3.29825319e-02,  8.69655516e-03,
#         2.02522967e-02,  1.52111858e-02,  8.87819735e-03,  7.02479174e-03,
#         2.63035105e-03,  1.29441357e-02,  1.78496234e-02, -6.61238891e-03,
#         3.82030339e-04])

# %%
lr.coef_.shape
# Out:
# (105,)

# %%
coef_df = pd.DataFrame(lr.coef_.reshape(1,105),columns = x.columns).stack().reset_index().drop(columns = ['level_0']).rename(columns ={'level_1' : 'feature' , 0:'coef' })

# %%
coef_df
# Out:
#                               feature      coef
# 0                       property_type  0.110405
# 1                             bedRoom  0.051070
# 2                            bathroom  0.063896
# 3                       built_up_area  0.223110
# 4                        servant room  0.048669
# ..                                ...       ...
# 100                  sector_sector 95  0.002630
# 101                  sector_sector 99  0.012944
# 102                 sector_sohna road  0.017850
# 103                 agePossession_old -0.006612
# 104  agePossession_under construction  0.000382
#
# [105 rows x 2 columns]

# %%
import statsmodels.api as sm
x_with_const = sm.add_constant(x_scaled)

model = sm.OLS(y_log , x_with_const).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     214.0
# Date:                Sat, 21 Jun 2025   Prob (F-statistic):               0.00
# Time:                        01:31:37   Log-Likelihood:                 615.00
# No. Observations:                3554   AIC:                            -1018.
# Df Residuals:                    3448   BIC:                            -363.4
# Df Model:                         105
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                                1.0463      0.003    301.870      0.000       1.039       1.053
# property_type                        0.1104      0.005     21.328      0.000       0.100       0.121
# bedRoom                              0.0511      0.007      7.834      0.000       0.038       0.064
# bathroom                             0.0639      0.007      9.475      0.000       0.051       0.077
# built_up_area                        0.2231      0.005     43.847      0.000       0.213       0.233
# servant room                         0.0487      0.004     10.900      0.000       0.040       0.057
# furnishing_type                     -0.0017      0.004     -0.454      0.650      -0.009       0.006
# luxury_category                      0.0043      0.004      1.077      0.281      -0.003       0.012
# sector_sector 10                     0.0159      0.004      4.190      0.000       0.008       0.023
# sector_sector 102                    0.0635      0.007      9.176      0.000       0.050       0.077
# sector_sector 103                    0.0201      0.005      3.893      0.000       0.010       0.030
# sector_sector 104                    0.0328      0.006      5.567      0.000       0.021       0.044
# sector_sector 105                   -0.0017      0.004     -0.393      0.694      -0.010       0.007
# sector_sector 106                    0.0230      0.005      4.582      0.000       0.013       0.033
# sector_sector 107                    0.0146      0.006      2.571      0.010       0.003       0.026
# sector_sector 108                    0.0427      0.006      7.551      0.000       0.032       0.054
# sector_sector 109                    0.0572      0.006      8.882      0.000       0.045       0.070
# sector_sector 11                     0.0003      0.004      0.070      0.944      -0.008       0.009
# sector_sector 110                    0.0251      0.004      5.633      0.000       0.016       0.034
# sector_sector 111                    0.0334      0.004      7.553      0.000       0.025       0.042
# sector_sector 112                    0.0462      0.005     10.245      0.000       0.037       0.055
# sector_sector 113                    0.0577      0.005     11.130      0.000       0.047       0.068
# sector_sector 12                     0.0017      0.005      0.345      0.730      -0.008       0.011
# sector_sector 13                    -0.0012      0.004     -0.302      0.762      -0.009       0.006
# sector_sector 14                     0.0448      0.004     10.348      0.000       0.036       0.053
# sector_sector 15                     0.0129      0.004      3.432      0.001       0.006       0.020
# sector_sector 17                     0.0257      0.004      6.509      0.000       0.018       0.033
# sector_sector 2                      0.0354      0.006      6.252      0.000       0.024       0.046
# sector_sector 21                 -3.044e-05      0.004     -0.008      0.994      -0.007       0.007
# sector_sector 22                     0.0529      0.004     12.199      0.000       0.044       0.061
